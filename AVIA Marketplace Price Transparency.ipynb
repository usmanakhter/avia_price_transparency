# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("white")
sns.set()

# %% [markdown]
# # <font color = green>Price Transparency</font>
# The AVIA Marketplace lacks price transparency. Below are the prices on all items in the Marketplace.

# %% [markdown]
# [AVIA Marketplace Price Transparency Spreadsheet](https://drive.google.com/open?id=198OluXOtVzZ6Icd6EiI54ygvMnXWUbyU-cTiiqFfau4)

# %%
df=pd.read_csv("avia_marketplace.csv")

# %%
print(df.to_string())
# Out:
#                                                   item  price
# 0                                   dang coconut chips   2.99
# 1                               mr. cheese o's cheddar   2.42
# 2                              mr. cheese o's parmesan   2.42
# 3                orchard valley almonds dark chocolate   2.12
# 4                           planters turtle sundae mix   2.79
# 5                       appleways cinnaon crispy bites   1.44
# 6               appleways blueberry lemon crispy bites   1.44
# 7        orchard valley chocolate raisin nut trail mix   2.39
# 8                             black forest juicy burst   1.25
# 9    purely elizabeth blueberry hemp ancient grain ...   2.59
# 10                   darrell lea soft eating liquorice   3.51
# 11                              chex mix muddy buddies   2.49
# 12                            think beef jerky classic   3.99
# 13                     think beef jerky sweet chipotle   3.99
# ...

# %%
df_food=df[:162]
df_drinks=df[163:]

#piechart
labels = ['Food', 'Drinks']
sizes = [len(df_food), len(df_drinks)]
colors = ['green', 'orange']
explode = (0.1, 0.1)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %% [markdown]
# ### <font color=green>What are the cheapest items?</font>

# %%
sns.catplot(y="price", kind="swarm", color="green", data=df_food);
sns.catplot(y="price", kind="swarm", color="orange", data=df_drinks);

# %% [markdown]
# The largest cluster of food prices are at \$1. That's also one of the lowest food prices available, with just a handful of items under \$1. Drinks are less clustered. Most drinks fall under \$3.

# %%
df_food.query('price <= 1').sort_values('price')
# Out:
#                                               item  price
# 161                                     clementine   0.50
# 158                           cheddar cheese chunk   0.68
# 55             snyder's hanover sourdough nibblers   0.75
# 160                                          apple   0.75
# 159                                  string cheese   0.88
# 110               nature' bakery blueberry fig bar   0.98
# 113                   nature valley oats 'n honey    0.99
# 92             popcorners white cheddar corn chips   0.99
# 127         nature valley sweet & salty nut almond   0.99
# 117                                starburst minis   1.00
# 116                                      twizzlers   1.00
# 112           nature valley oats 'n dark chocolate   1.00
# 66                            doritos nacho cheese   1.00
# 102                                   newton's fig   1.00
# 84                            chex mix traditional   1.00
# ...

# %% [markdown]
# It shouldn't be surprising that the most processed snacks are the cheapest. Fortunately, apples and clementines are even cheaper! And what's that item way up there at \$5.00? Creminelli Casalingo Salami Aged Gouda and Dried Cherries.

# %%
df_drinks.query('price <= 2').sort_values('price')
# Out:
#                                  item  price
# 163                         soda cans   1.00
# 164  la croix pamplemousse grapefruit   1.00
# 165                  la croix coconut   1.03
# 178                     v8 low sodium   1.35
# 177                     sanpellegrino   1.40
# 181                 mtn dew kickstart   1.49
# 182              s. pellegrino bottle   1.49
# 193                 snapple peach tea   1.59
# 197                       smart water   1.75
# 194                       soda bottle   1.75
# 188               a&w rootbeer bottle   1.75
# 200                          aquafina   1.75
# 199                            dasani   1.75
# 184                      coke bottles   1.75
# 176       prarie farms chocolate milk   1.79
# 172          lifeway kefir strawberry   1.89
# 196                          gatorade   1.89
# 166         spindrift sparkling water   1.89
# 183                           perrier   1.90
# 190                 minute maid juice   1.95
# ...

# %% [markdown]
# Unsurprisingly, soda (pop?) cans are the cheapest drink, with La Croix also at \$1. And what's that drink up there at $5.30? Health-Ade Kombucha Ginger-Lemon.

# %% [markdown]
# ### <font color =green>What Should I Get? (WIP)</font>
# -purchasing decision analysis
# <br>--by type of snacks/drinks
# <br>--by money constraint / utility

# %% [markdown]
# ### <font color =green>Pricing Analysis (WIP)</font>
# <br>--by type of food/drink
# <br>--by flavor
